# %% [markdown]
# <a href="https://colab.research.google.com/github/lmorrison777/umbc_data_690_fall_2024/blob/main/Lauren_Assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 05

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

df.shape
# Out:
# (4123, 9)

# %%
df.sample(5)
# Out:
#       Year       Country  GDP per capita (current US$)  \
# 871   2020   Congo, Rep.                   2011.269479
# 725   2007          Chad                    806.710319
# 934   2007          Cuba                   4814.854876
# 256   2013  Bahamas, The                  26955.788928
# 1090  2011       Ecuador                   5202.656459
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 871                                    63.785          5702174.0          COG
# 725                                    48.751         10722731.0          TCD
# 934                                    77.307         11269887.0          CUB
# 256                                    73.024           385650.0          BHS
# 1090                                   75.743         15237728.0          ECU
#
#                           Region         Income Group    Lending Type
# 871          Sub-Saharan Africa   Lower middle income           Blend
# 725          Sub-Saharan Africa            Low income             IDA
# 934   Latin America & Caribbean   Upper middle income  Not classified
# 256   Latin America & Caribbean           High income  Not classified
# 1090  Latin America & Caribbean   Upper middle income            IBRD

# %%
df.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               161
# Life expectancy at birth, total (years)    346
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df[["Year", "Country","GDP per capita (current US$)", "Life expectancy at birth, total (years)"]].sample(5)
# Out:
#       Year               Country  GDP per capita (current US$)  \
# 916   2008               Croatia                  15898.799896
# 3689  2007                  Togo                    621.734576
# 1268  2018                  Fiji                   6073.394579
# 1636  2006  Hong Kong SAR, China                  28224.095156
# 1216  2004              Ethiopia                    134.542486
#
#       Life expectancy at birth, total (years)
# 916                                 75.912195
# 3689                                56.511000
# 1268                                67.810000
# 1636                                82.375610
# 1216                                53.235000

# %%
df_2022 = df[df["Year"] != 2022]
df_2022.shape
# Out:
# (3906, 9)

# %%
df_2022.isna().sum()
# Out:
# Year                                         0
# Country                                      0
# GDP per capita (current US$)               140
# Life expectancy at birth, total (years)    129
# Population, total                            0
# Country Code                                 0
# Region                                       0
# Income Group                                 0
# Lending Type                                 0
# dtype: int64

# %%
df_2022 = df_2022.dropna()
df_2022.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               0
# Life expectancy at birth, total (years)    0
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2022.shape
# Out:
# (3641, 9)

# %% [markdown]
# ## Homework Question 1:
#
# to check if this dataset has duplicate rows. If it has, only keep one from the duplicated rows and drop the rest.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year, Country, GDP per capita (current US$), Life expectancy at birth, total (years), Population, total, Country Code, Region, Income Group, Lending Type]
# Index: []

# %%
df_cleaned = df.drop_duplicates()

print(f"Cleaned shape: {df_cleaned.shape}")
print(df_cleaned.sample(5))
# Out:
# Cleaned shape: (4123, 9)
#       Year       Country  GDP per capita (current US$)  \
# 913   2005       Croatia                  10446.361489
# 253   2010  Bahamas, The                  27046.657665
# 1121  2004   El Salvador                   2273.955503
# 382   2006         Benin                    837.132002
# 271   2009       Bahrain                  19448.183255
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 913                                 75.244634          4310145.0          HRV
# 253                                 72.731000           373272.0          BHS
# 1121                                70.340000          6035655.0          SLV
# 382                                 57.456000          8402631.0          BEN
# 271                                 78.461000          1179453.0          BHR
#
#                           Region         Income Group    Lending Type
# 913        Europe & Central Asia          High income            IBRD
# 253   Latin America & Caribbean           High income  Not classified
# 1121  Latin America & Caribbean   Upper middle income            IBRD
# 382          Sub-Saharan Africa   Lower middle income             IDA
# 271   Middle East & North Africa          High income  Not classified

# %% [markdown]
# ## HW Question 2
#
# Find out if there is a relationship between wealth and health
#
# Pick any year worth of data and use plotly express to generate a scatter plot with GDP as x and life expectancy as y.

# %%
year_of_interest = 2019

df_2019 = df[df["Year"] == year_of_interest]
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (217, 9)
#       Year          Country  GDP per capita (current US$)  \
# 1763  2019             Iraq                   5621.181695
# 3340  2019  Solomon Islands                   2398.773050
# 1003  2019          Czechia                  23664.847863
# 2485  2019           Monaco                 199382.838585
# 946   2019             Cuba                   9139.380510
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 1763                                71.576000         41563520.0          IRQ
# 3340                                70.382000           674993.0          SLB
# 1003                                79.229268         10671870.0          CZE
# 2485                                      NaN            37034.0          MCO
# 946                                 77.611000         11316697.0          CUB
#
#                           Region         Income Group    Lending Type
# 1763  Middle East & North Africa  Upper middle income            IBRD
# 3340         East Asia & Pacific  Lower middle income             IDA
# 1003       Europe & Central Asia          High income  Not classified
# 2485       Europe & Central Asia          High income  Not classified
# 946   Latin America & Caribbean   Upper middle income  Not classified

# %%
df_2019.isna().sum()
# Out:
# Year                                       0
# Country                                    0
# GDP per capita (current US$)               6
# Life expectancy at birth, total (years)    8
# Population, total                          0
# Country Code                               0
# Region                                     0
# Income Group                               0
# Lending Type                               0
# dtype: int64

# %%
df_2019 = df_2019.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])
print(df_2019.shape)
df_2019.sample(5)
# Out:
# (203, 9)
#       Year        Country  GDP per capita (current US$)  \
# 243   2019     Azerbaijan                   4805.753718
# 1402  2019        Germany                  46805.138433
# 927   2019        Croatia                  15120.902903
# 2675  2019  New Caledonia                  34934.579430
# 3036  2019          Qatar                  62827.396954
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 243                                 73.102000         10024283.0          AZE
# 1402                                81.292683         83092962.0          DEU
# 927                                 78.424390          4065253.0          HRV
# 2675                                80.419707           271240.0          NCL
# 3036                                80.990000          2807235.0          QAT
#
#                           Region         Income Group    Lending Type
# 243        Europe & Central Asia  Upper middle income            IBRD
# 1402       Europe & Central Asia          High income  Not classified
# 927        Europe & Central Asia          High income            IBRD
# 2675         East Asia & Pacific          High income  Not classified
# 3036  Middle East & North Africa          High income  Not classified

# %%
fig = px.scatter(
    df_2019,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    size="Population, total",
    title=f"Relationship between GDP per Capita and Life Expectancy in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7b25676-eb02-445c-a701-6bd8592578d8" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7b25676-eb02-445c-a701-6bd8592578d8")) {                    Plotly.newPlot(                        "a7b25676-eb02-445c-a701-6bd8592578d8",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[37769499.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Afghanistan","orientation":"v","showlegend":true,"x":[497.741429257502],"xaxis":"x","y":[63.565],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Albania\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#EF553B","size":[2854191.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Albania","orientation":"v","showlegend":true,"x":[5396.2142432843],"xaxis":"x","y":[79.282],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Algeria\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#00cc96","size":[42705368.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Algeria","orientation":"v","showlegend":true,"x":[4021.9832660524],"xaxis":"x","y":[76.474],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Angola\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","marker":{"color":"#ab63fa","size":[32353588.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Angola","orientation":"v","showlegend":true,"x":[2191.34776373555],"xaxis":"x","y":[62.448],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Antigua and Barbuda\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Antigua and Barbuda","marker":{"color":"#FFA15A","size":[92117.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Antigua and Barbuda","orientation":"v","showlegend":true,"x":[18730.0047966374],"xaxis":"x","y":[78.691],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Argentina\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#19d3f3","size":[44938712.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Argentina","orientation":"v","showlegend":true,"x":[9963.67416171662],"xaxis":"x","y":[77.284],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Armenia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#FF6692","size":[2820602.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers","name":"Armenia","orientation":"v","showlegend":true,"x":[4828.50488626598],"xaxis":"x","y":[75.439],"yaxis":"y"," ...

# %% [markdown]
# ## Compare China, US, India, Russia

# %%
df_4_countries = df_2019[df_2019["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_4_countries.shape)
df_4_countries
# Out:
# (4, 9)
#       Year             Country  GDP per capita (current US$)  \
# 794   2019               China                  10143.860221
# 1706  2019               India                   2050.163800
# 3074  2019  Russian Federation                  11536.258789
# 3929  2019       United States                  65120.394663
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 794                                 77.968000       1.407745e+09          CHN
# 1706                                70.910000       1.383112e+09          IND
# 3074                                73.083902       1.444063e+08          RUS
# 3929                                78.787805       3.283300e+08          USA
#
#                      Region         Income Group    Lending Type
# 794     East Asia & Pacific  Upper middle income            IBRD
# 1706             South Asia  Lower middle income            IBRD
# 3074  Europe & Central Asia  Upper middle income            IBRD
# 3929          North America          High income  Not classified

# %%
fig = px.scatter(
    df_4_countries,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"Compare Wealth and Health of Four Major World Powers {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    },
    height=600,
    width=1000
)

# Update text position
fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=55000,  # X coordinate
    y=71,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="539abafd-1080-4584-ab20-75d7a46546ef" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("539abafd-1080-4584-ab20-75d7a46546ef")) {                    Plotly.newPlot(                        "539abafd-1080-4584-ab20-75d7a46546ef",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#636efa","size":[1407745000.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"China","orientation":"v","showlegend":true,"text":["China"],"x":[10143.8602205959],"xaxis":"x","y":[77.968],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","marker":{"color":"#EF553B","size":[1383112050.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"India","orientation":"v","showlegend":true,"text":["India"],"x":[2050.1638002619],"xaxis":"x","y":[70.91],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","marker":{"color":"#00cc96","size":[144406261.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation"],"x":[11536.2587890625],"xaxis":"x","y":[73.0839024390244],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","marker":{"color":"#ab63fa","size":[328329953.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"United States","orientation":"v","showlegend":true,"text":["United States"],"x":[65120.3946628653],"xaxis":"x","y":[78.7878048780488],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888 ...

# %%
df_quad = df[df["Country Code"].isin(["USA", "CHN", "IND", "RUS"])]
print(df_quad.shape)
df_quad.sample(5)
# Out:
# (76, 9)
#       Year             Country  GDP per capita (current US$)  \
# 3076  2021  Russian Federation                  12532.050781
# 793   2018               China                   9905.406383
# 1697  2010               India                   1350.634470
# 3066  2011  Russian Federation                  14311.064453
# 3077  2022  Russian Federation                  15270.706055
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3076                                69.361220       1.441305e+08          RUS
# 793                                 77.744000       1.402760e+09          CHN
# 1697                                66.909000       1.240614e+09          IND
# 3066                                69.683902       1.429609e+08          RUS
# 3077                                      NaN       1.442369e+08          RUS
#
#                      Region         Income Group Lending Type
# 3076  Europe & Central Asia  Upper middle income         IBRD
# 793     East Asia & Pacific  Upper middle income         IBRD
# 1697             South Asia  Lower middle income         IBRD
# 3066  Europe & Central Asia  Upper middle income         IBRD
# 3077  Europe & Central Asia  Upper middle income         IBRD

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4774ccbe-65af-48bd-bd2d-fdc10a1630da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4774ccbe-65af-48bd-bd2d-fdc10a1630da")) {                    Plotly.newPlot(                        "4774ccbe-65af-48bd-bd2d-fdc10a1630da",                        [{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=India\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Russian Federation\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Russian Federation","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=United States\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[41724.6316287624,44123.4070679055,46302.0008800056,48050.2237771135,48570.0459804586,47194.9433547336,48650.6431283336,50065.9665041742,51784.4185738837,53291.1276891406,55123.8497869046,56762.7294515989,57866.7449341091,59907.754260885,62823.309438197,65120.3946628653,63528.6343027508,70219.472454115,76329.5822652029],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555555555 ...

# %% [markdown]
# ## 10/9/20204 Homework Question 1:
#
# for the Quad time series comparison chart above, try to add country name to the end of the line and then remove the color legend.

# %%
df_quad.sample(5)
# Out:
#       Year             Country  GDP per capita (current US$)  \
# 782   2007               China                   2693.958732
# 795   2020               China                  10408.719554
# 3065  2010  Russian Federation                  10674.990234
# 3918  2008       United States                  48570.045980
# 3919  2009       United States                  47194.943355
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 782                                 74.762000       1.317885e+09          CHN
# 795                                 78.077000       1.411100e+09          CHN
# 3065                                68.841220       1.428495e+08          RUS
# 3918                                78.039024       3.040940e+08          USA
# 3919                                78.390244       3.067715e+08          USA
#
#                      Region         Income Group    Lending Type
# 782     East Asia & Pacific  Upper middle income            IBRD
# 795     East Asia & Pacific  Upper middle income            IBRD
# 3065  Europe & Central Asia  Upper middle income            IBRD
# 3918          North America          High income  Not classified
# 3919          North America          High income  Not classified

# %%
fig = px.line(
    df_quad,
    x="Year",
    color="Country",
    y="GDP per capita (current US$)",
    text = "Country"
)

fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fa2c405c-7c3c-4808-a3f4-25680254a960" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa2c405c-7c3c-4808-a3f4-25680254a960")) {                    Plotly.newPlot(                        "fa2c405c-7c3c-4808-a3f4-25680254a960",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"China","orientation":"v","showlegend":true,"text":["China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China","China"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[1508.66791563578,1753.41419162417,2099.2194300786,2693.95873162278,3468.32706308591,3832.22745696438,4550.47394361131,5614.3860223103,6300.58217952904,7020.38607424065,7636.0743401587,8016.44559491162,8094.39016730811,8817.04560829162,9905.40638307759,10143.8602205959,10408.7195541075,12617.5051041181,12720.2163182363],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"India","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"India","orientation":"v","showlegend":true,"text":["India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India","India"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[624.105094381691,710.509344848758,802.013742049265,1022.73246704551,993.503405266506,1096.63613605519,1350.63447029491,1449.60330101563,1434.01798721629,1438.05700508042,1559.86377870535,1590.17433135955,1714.27953740039,1957.96981329558,1974.3777314935,2050.1638002619,1913.21973278751,2238.12714218765,2410.88802070689],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Russian Federation","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"Russian Federation","orientation":"v","showlegend":true,"text":["Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation","Russian Federation"],"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[4102.36474609375,5323.455078125,6920.19970703125,9101.2392578125,11635.2841796875,8562.82421875,10674.990234375,14311.064453125,15420.859375,15974.6220703125,14095.646484375,9313.021484375,8704.89453125,10720.33203125,11287.3544921875,11536.2587890625,10194.44140625,12532.05078125,15270.7060546875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=%{text}\u003cbr\u003eYear=%{x}\u003cbr\u003eGDP per capita (current US$)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"United States","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers+text","name":"United States","orientation":"v","showlegend":true,"text":[" ...

# %%
df_group = df.groupby(["Year", "Region"])["Population, total"].sum().reset_index()
df_group.sample(5)
# Out:
#      Year                      Region  Population, total
# 91   2017         East Asia & Pacific       2.303580e+09
# 61   2012                  South Asia       1.708707e+09
# 112  2020         East Asia & Pacific       2.340351e+09
# 33   2008                  South Asia       1.612709e+09
# 101  2018  Middle East & North Africa       4.650735e+08

# %% [markdown]
# Home work #5
# Pick a few countries of your interest (for example, G7, BRICS, Nordic countries).
# - 1 Create a line chart showing the trend of Life Expectancy over time for comparing those countries.
# - 2 Pick a year from the data of the above few countries and create a scatter plot to compare their GDP per capita and life expectancy. The size of the dots represent the population. This type of scatter plot is called bubble chart.
# - 3 Bonus - compute the average GDP per capita, the average life expectancy, and the total population for each year of all the seven regions (aggregation) and repeat 1 and 2 using the aggregated data for all regions

# %% [markdown]
# ## Question 1:

# %%
import random

# Select 10 random countries
random_countries = random.sample(list(df["Country"].unique()), 10)

# Filter the DataFrame to include only the selected countries
df_random_countries = df[df["Country"].isin(random_countries)]

# Create a line chart showing the trend of Life Expectancy over time
fig = px.line(
    df_random_countries,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Country",
    title="Life Expectancy Trend for 10 Random Countries",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5cde1501-4a31-4739-aa32-cd4486938941" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cde1501-4a31-4739-aa32-cd4486938941")) {                    Plotly.newPlot(                        "5cde1501-4a31-4739-aa32-cd4486938941",                        [{"hovertemplate":"Country=Bangladesh\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bangladesh","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[67.187,67.299,67.241,66.714,67.051,67.403,68.638,68.809,69.554,69.565,69.986,70.491,71.09,71.788,72.567,72.806,71.968,72.381,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=China\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"China","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[73.748,74.111,74.504,74.762,74.872,75.343,75.599,75.903,76.192,76.452,76.717,76.977,77.218,77.248,77.744,77.968,78.077,78.211,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Ecuador\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ecuador","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[74.279,74.514,74.689,74.844,74.983,75.184,75.43,75.743,76.062,76.369,76.622,76.789,76.763,76.972,77.094,77.297,72.153,73.67,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Eswatini\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eswatini","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Eswatini","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[42.538,42.125,43.12,43.641,44.175,44.639,46.619,48.195,49.835,51.486,53.05,55.019,56.659,57.895,59.411,60.549,59.692,57.066,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Israel\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Israel","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Israel","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[80.1463414634146,80.1512195121951,80.5536585365854,80.5048780487805,80.9512195121951,81.4048780487805,81.6024390243903,81.6560975609756,81.7048780487805,82.0560975609756,82.1536585365854,82.0512195121951,82.4073170731707,82.5512195121951,82.8024390243903,82.8048780487805,82.6487804878049,82.5,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Country=Nicaragua\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nicaragua","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Nicaragua","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2 ...

# %% [markdown]
# ## Question 2

# %%
year_of_interest = 2019

df_random_countries_year = df_random_countries[df_random_countries["Year"] == year_of_interest]

df_random_countries_year = df_random_countries_year.dropna(subset=["GDP per capita (current US$)", "Life expectancy at birth, total (years)"])

fig = px.scatter(
    df_random_countries_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Country",
    text="Country",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for 10 Random Countries in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.update_traces(textposition='top center')
fig.update_layout(showlegend=False)
# Add an annotation
fig.add_annotation(
    x=70000,  # X coordinate
    y=60,     # Y coordinate
    text="Note: The size of the dot represents the population.",  # Annotation text
    showarrow=False  # Do not show arrow
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a284357b-4607-464a-8e10-16d616ce7a19" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a284357b-4607-464a-8e10-16d616ce7a19")) {                    Plotly.newPlot(                        "a284357b-4607-464a-8e10-16d616ce7a19",                        [{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bangladesh","marker":{"color":"#636efa","size":[165516222.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Bangladesh","orientation":"v","showlegend":true,"text":["Bangladesh"],"x":[2122.07839667492],"xaxis":"x","y":[72.806],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"China","marker":{"color":"#EF553B","size":[1407745000.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"China","orientation":"v","showlegend":true,"text":["China"],"x":[10143.8602205959],"xaxis":"x","y":[77.968],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ecuador","marker":{"color":"#00cc96","size":[17343740.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Ecuador","orientation":"v","showlegend":true,"text":["Ecuador"],"x":[6233.25816692363],"xaxis":"x","y":[77.297],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Eswatini","marker":{"color":"#ab63fa","size":[1169613.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Eswatini","orientation":"v","showlegend":true,"text":["Eswatini"],"x":[3818.54048403065],"xaxis":"x","y":[60.549],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Israel","marker":{"color":"#FFA15A","size":[9054000.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Israel","orientation":"v","showlegend":true,"text":["Israel"],"x":[44452.2325623093],"xaxis":"x","y":[82.8048780487805],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nicaragua","marker":{"color":"#19d3f3","size":[6663924.0],"sizemode":"area","sizeref":3519362.5,"symbol":"circle"},"mode":"markers+text","name":"Nicaragua","orientation":"v","showlegend":true,"text":["Nicaragua"],"x":[1905.63832831484],"xaxis":"x","y":[74.054],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Country=%{text}\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u00 ...

# %% [markdown]
# ## Question 3 : Bonus

# %%
# Group by Year and Region, calculate average GDP per capita, average life expectancy, and total population
df_region_agg = df.groupby(["Year", "Region"]).agg(
    {
        "GDP per capita (current US$)": "mean",
        "Life expectancy at birth, total (years)": "mean",
        "Population, total": "sum"
    }
).reset_index()

df_region_agg.sample(5)
# Out:
#      Year                      Region  GDP per capita (current US$)  \
# 116  2020               North America                  71556.732864
# 40   2009                  South Asia                   1781.421550
# 101  2018  Middle East & North Africa                  16439.887429
# 37   2009  Latin America & Caribbean                   11703.170891
# 68   2013                  South Asia                   2424.430926
#
#      Life expectancy at birth, total (years)  Population, total
# 116                                79.928992       3.695826e+08
# 40                                 67.416750       1.636412e+09
# 101                                75.545677       4.650735e+08
# 37                                 73.643408       5.827381e+08
# 68                                 69.570000       1.731684e+09

# %%
# Create a line chart showing the trend of Life Expectancy over time for all regions
fig = px.line(
    df_region_agg,
    x="Year",
    y="Life expectancy at birth, total (years)",
    color="Region",
    title="Life Expectancy Trend for All Regions",
    labels={
        "Year": "Year",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="49de6e15-d5b6-4e45-9815-cb3735c05adc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49de6e15-d5b6-4e45-9815-cb3735c05adc")) {                    Plotly.newPlot(                        "49de6e15-d5b6-4e45-9815-cb3735c05adc",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[70.82474605451937,71.03525226480836,71.35182855093257,71.53284791965567,71.55289167862267,71.93134289813486,72.1956987087518,72.4136262553802,72.63352725968436,72.85580703012913,73.06722883787661,73.2169756097561,73.38525538020087,73.59137517934003,73.8483737446198,74.0432230989957,74.14365566714491,73.64341893830704,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[74.8951915742794,74.99792727272728,75.27233303769401,75.49948070953438,75.9008713968958,76.20778137472284,76.45108115299335,76.83067450110866,77.04216097560976,77.25882793791575,77.56068115299334,77.53420044345899,77.83207627494457,77.99858669623062,78.13177738359202,78.39830288248336,77.36474589800444,77.08593215077606,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.3771243307555,72.71504045211184,72.99729625223081,73.12531290898275,73.37290660321237,73.64340809042237,73.50570969660916,73.93912790005949,74.13676740035693,74.24663176680548,74.42811957168352,74.51728494943485,74.63538548483046,74.5883503866746,74.79783780487804,74.75240731707316,73.94311280487804,72.96878231707316,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[72.37166666666667,72.64277235772359,72.80688966318235,73.09993147502904,73.40060975609757,73.75654006968641,74.1584761904762,74.24478281068525,74.24767711962834,74.37635423925667,74.45095238095239,74.7327038327526,74.97042740998839,75.34821718931474,75.54567711962834,75.72125783972126,74.67093147502904,74.36790360046457,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eYear=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cextra\u003e\u003c\u002fext ...

# %%
# Pick a year from the data and create a scatter plot to compare their GDP per capita and life expectancy.
year_of_interest = 2019
df_region_agg_year = df_region_agg[df_region_agg["Year"] == year_of_interest]

fig = px.scatter(
    df_region_agg_year,
    x="GDP per capita (current US$)",
    y="Life expectancy at birth, total (years)",
    color="Region",
    size="Population, total",
    title=f"GDP per Capita vs. Life Expectancy for All Regions in {year_of_interest}",
    labels={
        "GDP per capita (current US$)": "GDP per Capita (Current US$)",
        "Life expectancy at birth, total (years)": "Life Expectancy (Years)"
    }
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="52bd2f0b-fa1d-45c5-98a3-eca044dec573" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("52bd2f0b-fa1d-45c5-98a3-eca044dec573")) {                    Plotly.newPlot(                        "52bd2f0b-fa1d-45c5-98a3-eca044dec573",                        [{"hovertemplate":"Region=East Asia & Pacific\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","size":[2330265835.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"East Asia & Pacific","orientation":"v","showlegend":true,"x":[17906.003161543427],"xaxis":"x","y":[74.0432230989957],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Europe & Central Asia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","size":[920277481.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Europe & Central Asia","orientation":"v","showlegend":true,"x":[35566.32252548241],"xaxis":"x","y":[78.39830288248336],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Latin America & Caribbean \u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","size":[645295804.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Latin America & Caribbean ","orientation":"v","showlegend":true,"x":[15465.703305292674],"xaxis":"x","y":[74.75240731707316],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Middle East & North Africa\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","size":[473201775.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"Middle East & North Africa","orientation":"v","showlegend":true,"x":[16111.826427618016],"xaxis":"x","y":[75.72125783972126],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=North America\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","size":[365995094.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"North America","orientation":"v","showlegend":true,"x":[75882.5711787408],"xaxis":"x","y":[80.68319512195124],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=South Asia\u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","size":[1861598514.0],"sizemode":"area","sizeref":5825664.5875,"symbol":"circle"},"mode":"markers","name":"South Asia","orientation":"v","showlegend":true,"x":[3286.247982757694],"xaxis":"x","y":[71.38875],"yaxis":"y","type":"scatter"},{"hovertemplate":"Region=Sub-Saharan Africa \u003cbr\u003eGDP per Capita (Current US$)=%{x}\u003cbr\u003eLife Expectancy (Years)=%{y}\u003cbr\u003ePopulation, total=%{marker.size}\u003cextra\u003e\u003c\u002fext ...

# %% [markdown]
# ## Homework Question 3
#
# Select a year of data. calculate total population of each region and make a pie chart to display the distribution of total population of all regions.

# %%
print(df.shape)
df.sample(10)
# Out:
# (4123, 9)
#       Year                Country  GDP per capita (current US$)  \
# 3335  2014        Solomon Islands                   2235.733703
# 162   2014                Armenia                   4017.229914
# 1832  2012                  Italy                  35051.521270
# 2438  2010  Micronesia, Fed. Sts.                   2760.011340
# 3300  2017        Slovak Republic                  17585.197002
# 1521  2005              Guatemala                   2068.488206
# 480   2009               Botswana                   4938.249906
# 1200  2007               Eswatini                   3200.512571
# 557   2010               Bulgaria                   6863.667068
# 3220  2013             Seychelles                  14729.626623
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 3335                                69.234000           597375.0          SLB
# 162                                 74.058000          2889930.0          ARM
# 1832                                82.239024         59539717.0          ITA
# 2438                                71.233000           107588.0          FSM
# 3300                                77.165854          5439232.0          SVK
# 1521                                69.168000         12948292.0          GTM
# 480                                 58.279000          2048997.0          BWA
# 1200                                43.641000          1084008.0          SWZ
# 557                                 73.512195          7395599.0          BGR
# 3220                                73.119512            89949.0          SYC
#
#                           Region         Income Group    Lending Type
# 3335         East Asia & Pacific  Lower middle income             IDA
# 162        Europe & Central Asia  Upper middle income            IBRD
# 1832       Europe & Central Asia          High income  Not classified
# 2438         East Asia & Pacific  Lower middle income             IDA
# 3300       Europe & Central Asia          High income  Not classified
# 1521  Latin America & Caribbean   Upper middle income            IBRD
# 480          Sub-Saharan Africa   Upper middle income            IBRD
# 1200         Sub-Saharan Africa   Lower middle income            IBRD
# 557        Europe & Central Asia  Upper middle income            IBRD
# 3220         Sub-Saharan Africa           High income            IBRD

# %%
df["Year"].unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022])

# %%
df_filtered = df[df["Year"] == 2010].dropna(subset=["Population, total", "GDP per capita (current US$)", "Region"])
print(df_filtered.shape)
df_filtered.sample(5)
# Out:
# (209, 9)
#       Year         Country  GDP per capita (current US$)  \
# 994   2010         Czechia                  19960.068487
# 652   2010        Cameroon                   1383.813865
# 3540  2010        Suriname                   7999.507394
# 2590  2010         Namibia                   5445.420063
# 3901  2010  United Kingdom                  39598.957120
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 994                                 77.424390         10474410.0          CZE
# 652                                 56.582000         19878036.0          CMR
# 3540                                69.894000           546080.0          SUR
# 2590                                56.015000          2099271.0          NAM
# 3901                                80.402439         62766365.0          GBR
#
#                           Region         Income Group    Lending Type
# 994        Europe & Central Asia          High income  Not classified
# 652          Sub-Saharan Africa   Lower middle income           Blend
# 3540  Latin America & Caribbean   Upper middle income            IBRD
# 2590         Sub-Saharan Africa   Upper middle income            IBRD
# 3901       Europe & Central Asia          High income  Not classified

# %%
population_by_region = df_filtered.groupby("Region")["Population, total"].sum().reset_index()

population_by_region
# Out:
#                        Region  Population, total
# 0         East Asia & Pacific       2.162379e+09
# 1       Europe & Central Asia       8.889814e+08
# 2  Latin America & Caribbean        5.886271e+08
# 3  Middle East & North Africa       3.979976e+08
# 4               North America       3.433972e+08
# 5                  South Asia       1.660546e+09
# 6         Sub-Saharan Africa        8.677708e+08

# %%
fig = px.pie(
    population_by_region,
    values='Population, total',
    names='Region',
    title=f"Total Population Distribution by Region in {year_of_interest}",
    labels={'Population, total': 'Total Population'},
    hole=0.3
)
# Update traces to show both number and percentage
fig.update_traces(textinfo='label+value+percent')
fig.update_layout(showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ede07be-7146-4ef3-bf4d-c56fb6b08f85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ede07be-7146-4ef3-bf4d-c56fb6b08f85")) {                    Plotly.newPlot(                        "5ede07be-7146-4ef3-bf4d-c56fb6b08f85",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.3,"hovertemplate":"Region=%{label}\u003cbr\u003eTotal Population=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["East Asia & Pacific","Europe & Central Asia","Latin America & Caribbean ","Middle East & North Africa","North America","South Asia","Sub-Saharan Africa "],"legendgroup":"","name":"","showlegend":true,"values":[2162378942.0,888981434.0,588627089.0,397997557.0,343397156.0,1660546144.0,867770770.0],"type":"pie","textinfo":"label+value+percent"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{ ...

# %% [markdown]
# ## Exercise
#
# Calculate average GDP per capita for  each region and make a bar chart.

# %%
gdp_by_region = df_filtered.groupby('Region').agg(
    {
        'GDP per capita (current US$)': 'mean'
    }
).reset_index()

gdp_by_region
# Out:
#                        Region  GDP per capita (current US$)
# 0         East Asia & Pacific                  14068.845158
# 1       Europe & Central Asia                  31303.467052
# 2  Latin America & Caribbean                   12172.214861
# 3  Middle East & North Africa                  15578.718956
# 4               North America                  66029.336876
# 5                  South Asia                   2059.989661
# 6         Sub-Saharan Africa                    2310.375822

# %%
fig = px.bar(
    data_frame=gdp_by_region,
    x='Region',
    color="Region",
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9e6a69d2-64a7-406f-a0f3-af7151d0b6e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e6a69d2-64a7-406f-a0f3-af7151d0b6e9")) {                    Plotly.newPlot(                        "9e6a69d2-64a7-406f-a0f3-af7151d0b6e9",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"text":[14068.84515827713],"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[14068.84515827713],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"text":[31303.467051661613],"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[31303.467051661613],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":[12172.214860564287],"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[12172.214860564287],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"text":[15578.718955551416],"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15578.718955551416],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"text":[66029.33687569977],"textposition":"auto","x":["North America"],"xaxis":"x","y":[66029.33687569977],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"text":[2059.9896610305664],"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2059.9896610305664],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sub-Saharan Africa ","offsetgroup":"Sub-Saharan Africa ","orientation":"v","showlegend":true,"text":[2310.3758224682306],"textposition":"auto","x":["Sub-Saharan Africa "],"xaxis":"x","y":[2310.3758224682306],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogra ...

# %% [markdown]
# ## 10/09/2024 Homework Question 2
#
# Round the Average GDP for each region to 2 decimal points.
# Sort the bar according to GDP either in ascending order. Currently, it is ordered alphabetically.

# %%
fig = px.bar(
    data_frame=gdp_by_region,
    x='Region',
    color="Region",
    y='GDP per capita (current US$)',
    title='Average GDP per Capita by Region',
    labels={
        'GDP per capita (current US$)': 'Average GDP per Capita (Current US$)',
        'Region': 'Region'
    },
    text='GDP per capita (current US$)'
)
fig.update_layout(xaxis={'categoryorder':'total ascending'})
fig.update_traces(
    marker_line_width = 0,
    texttemplate = "%{value:.2f}"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="55052fee-07d2-4a08-b7c0-c7b8d12fc44d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55052fee-07d2-4a08-b7c0-c7b8d12fc44d")) {                    Plotly.newPlot(                        "55052fee-07d2-4a08-b7c0-c7b8d12fc44d",                        [{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Asia & Pacific","marker":{"color":"#636efa","pattern":{"shape":""},"line":{"width":0}},"name":"East Asia & Pacific","offsetgroup":"East Asia & Pacific","orientation":"v","showlegend":true,"text":[14068.84515827713],"textposition":"auto","x":["East Asia & Pacific"],"xaxis":"x","y":[14068.84515827713],"yaxis":"y","type":"bar","texttemplate":"%{value:.2f}"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Europe & Central Asia","marker":{"color":"#EF553B","pattern":{"shape":""},"line":{"width":0}},"name":"Europe & Central Asia","offsetgroup":"Europe & Central Asia","orientation":"v","showlegend":true,"text":[31303.467051661613],"textposition":"auto","x":["Europe & Central Asia"],"xaxis":"x","y":[31303.467051661613],"yaxis":"y","type":"bar","texttemplate":"%{value:.2f}"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Latin America & Caribbean ","marker":{"color":"#00cc96","pattern":{"shape":""},"line":{"width":0}},"name":"Latin America & Caribbean ","offsetgroup":"Latin America & Caribbean ","orientation":"v","showlegend":true,"text":[12172.214860564287],"textposition":"auto","x":["Latin America & Caribbean "],"xaxis":"x","y":[12172.214860564287],"yaxis":"y","type":"bar","texttemplate":"%{value:.2f}"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Middle East & North Africa","marker":{"color":"#ab63fa","pattern":{"shape":""},"line":{"width":0}},"name":"Middle East & North Africa","offsetgroup":"Middle East & North Africa","orientation":"v","showlegend":true,"text":[15578.718955551416],"textposition":"auto","x":["Middle East & North Africa"],"xaxis":"x","y":[15578.718955551416],"yaxis":"y","type":"bar","texttemplate":"%{value:.2f}"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""},"line":{"width":0}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"text":[66029.33687569977],"textposition":"auto","x":["North America"],"xaxis":"x","y":[66029.33687569977],"yaxis":"y","type":"bar","texttemplate":"%{value:.2f}"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"South Asia","marker":{"color":"#19d3f3","pattern":{"shape":""},"line":{"width":0}},"name":"South Asia","offsetgroup":"South Asia","orientation":"v","showlegend":true,"text":[2059.9896610305664],"textposition":"auto","x":["South Asia"],"xaxis":"x","y":[2059.9896610305664],"yaxis":"y","type":"bar","texttemplate":"%{value:.2f}"},{"alignmentgroup":"True","hovertemplate":"Region=%{x}\u003cbr\u003eAverage GDP per Capita (Current US$)=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sub-Saharan Africa ","marker":{"color":"#FF6692","pattern":{"shape":""},"lin ...

# %% [markdown]
# ## Home work question 4
#
# 1. remove the color legend.
# 2. Order the above bar chart based on the values of the average GDP per capita.

# %%
# Short cut to comment out many lines of code:
# First hightlight the code block
# then, hold down CTL, then press +/


# data = {
#     'Gender': ['Male', 'Female', 'Male', 'Female', 'Male'],
#     'Grade': ['A', 'B', 'A', 'A', 'B'],
#     'Score': [90, 85, 92, 88, 78]
# }

# df = pd.DataFrame(data)

# # Define the aggregate functions to be applied to the 'Score' column
# agg_functions = {
#     'Score': ['mean', 'max']
# }

# # Group by 'Gender' and 'Grade', then apply the aggregate functions
# grouped = df.groupby(['Gender', 'Grade']).aggregate(agg_functions)

# print(grouped)

# %%
df_2018 = df[df["Year"] == 2018]
print(df_2018.shape)
df_2018.sample(5)
# Out:
# (217, 9)
#       Year     Country  GDP per capita (current US$)  \
# 4099  2018      Zambia                   1475.199883
# 2560  2018  Mozambique                    510.379996
# 793   2018       China                   9905.406383
# 147   2018   Argentina                  11795.162745
# 2484  2018      Monaco                 193968.090133
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 4099                                   62.342       1.783589e+07          ZMB
# 2560                                   60.526       2.942388e+07          MOZ
# 793                                    77.744       1.402760e+09          CHN
# 147                                    76.999       4.449450e+07          ARG
# 2484                                      NaN       3.702900e+04          MCO
#
#                           Region         Income Group    Lending Type
# 4099         Sub-Saharan Africa   Lower middle income             IDA
# 2560         Sub-Saharan Africa            Low income             IDA
# 793          East Asia & Pacific  Upper middle income            IBRD
# 147   Latin America & Caribbean   Upper middle income            IBRD
# 2484       Europe & Central Asia          High income  Not classified

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    {
     'Life expectancy at birth, total (years)': ['min', 'mean', q1, "median", q3, 'max'],
     'GDP per capita (current US$)': ['min', 'mean', q1, "median", q3, 'max']
    }
)

df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                                min       mean
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                       \
#                                    q1   median         q3        max
# Region
# East Asia & Pacific         68.461500  72.1625  79.667823  84.934146
# Europe & Central Asia       75.013707  78.6960  81.760976  83.753659
# Latin America & Caribbean   73.127500  74.4680  77.073750  80.614000
# Middle East & North Africa  72.794000  76.0660  79.722000  82.802439
# North America               79.732012  80.8250  81.334451  81.843902
# South Asia                  68.354750  70.9195  73.362250  80.013000
# Sub-Saharan Africa          60.020750  62.3980  65.414500  75.733000
#
#                            GDP per capita (current US$)                \
#                                                     min          mean
# Region
# East Asia & Pacific                         1241.164485  18083.532845
# Europe & Central Asia                        850.666958  36165.933995
# Latin America & Caribbean                   1489.578406  15005.516403
# Middle East & North Africa                   701.714868  16439.887429
# North America                              46548.638411  74140.894910
# South Asia                                   492.090632   3249.655429
# Sub-Saharan Africa                           232.060617   2497.289753
#
#                                                                       \
#                                       q1        median            q3
# Region
# East Asia & Pacific          3249.086977   6598.976695  31792.165412
# Europe & Central Asia        7252.403668  23165.849479  51466.556563
# Latin America & Caribbean    6282.155427   9574.310271  18648.651035
# Middle East & North Africa   3562.330943   5601.467061  25415.846625
# North America               54685.973925  62823.309438  87937.023160
# South Asia                   1505.940531   1968.895112   3632.479161
# Sub-Saharan Africa            729.773250   1178.708534   2288.949504
#
#
#                                       max
# Region
# East Asia & Pacific          84779.453694
# Europe & Central Asia       193968.090133
# Latin America & Caribbean    85231.774254
# Middle East & North Africa   66264.081168
# North America               113050.736882
# South Asia                   11034.723597
# Sub-Saharan Africa           16411.921117

# %%
df_group.to_excel("by_region.xlsx")

# %%
df_group.to_csv("by_region.csv")

# %%
# df_group.rename(columns={"min":"Minimum","max":"Maximum"}, inplace=True)  Alternative

COLUMN_DICT = {
    "min":"Minimum",
    "max":"Maximum",
    "mean": "Average",
    "q1": "1st Quartile",
    "q3": "3rd quartile"
}

df_group = df_group.rename(columns=COLUMN_DICT)
df_group
# Out:
#                            Life expectancy at birth, total (years)             \
#                                                            Minimum    Average
# Region
# East Asia & Pacific                                      63.234000  73.848374
# Europe & Central Asia                                    68.796000  78.131777
# Latin America & Caribbean                                64.019000  74.797838
# Middle East & North Africa                               63.038000  75.545677
# North America                                            78.639024  80.435976
# South Asia                                               63.081000  71.088625
# Sub-Saharan Africa                                       52.554000  62.542100
#
#                                                                           \
#                            1st Quartile   median 3rd quartile    Maximum
# Region
# East Asia & Pacific           68.461500  72.1625    79.667823  84.934146
# Europe & Central Asia         75.013707  78.6960    81.760976  83.753659
# Latin America & Caribbean     73.127500  74.4680    77.073750  80.614000
# Middle East & North Africa    72.794000  76.0660    79.722000  82.802439
# North America                 79.732012  80.8250    81.334451  81.843902
# South Asia                    68.354750  70.9195    73.362250  80.013000
# Sub-Saharan Africa            60.020750  62.3980    65.414500  75.733000
#
#                            GDP per capita (current US$)                \
#                                                 Minimum       Average
# Region
# East Asia & Pacific                         1241.164485  18083.532845
# Europe & Central Asia                        850.666958  36165.933995
# Latin America & Caribbean                   1489.578406  15005.516403
# Middle East & North Africa                   701.714868  16439.887429
# North America                              46548.638411  74140.894910
# South Asia                                   492.090632   3249.655429
# Sub-Saharan Africa                           232.060617   2497.289753
#
#                                                                       \
#                             1st Quartile        median  3rd quartile
# Region
# East Asia & Pacific          3249.086977   6598.976695  31792.165412
# Europe & Central Asia        7252.403668  23165.849479  51466.556563
# Latin America & Caribbean    6282.155427   9574.310271  18648.651035
# Middle East & North Africa   3562.330943   5601.467061  25415.846625
# North America               54685.973925  62823.309438  87937.023160
# South Asia                   1505.940531   1968.895112   3632.479161
# Sub-Saharan Africa            729.773250   1178.708534   2288.949504
#
#
#                                   Maximum
# Region
# East Asia & Pacific          84779.453694
# Europe & Central Asia       193968.090133
# Latin America & Caribbean    85231.774254
# Middle East & North Africa   66264.081168
# North America               113050.736882
# South Asia                   11034.723597
# Sub-Saharan Africa           16411.921117

# %%
def q1(x):
    return x.quantile(0.25)

def q3(x):
    return x.quantile(0.75)



df_group = df_2018.groupby("Region").aggregate(
    Minimum=('Life expectancy at birth, total (years)', 'min'),
    Average=('Life expectancy at birth, total (years)', 'mean'),
    percentile_25=('Life expectancy at birth, total (years)', q1)
)

df_group
# Out:
#                               Minimum    Average  percentile_25
# Region
# East Asia & Pacific         63.234000  73.848374      68.461500
# Europe & Central Asia       68.796000  78.131777      75.013707
# Latin America & Caribbean   64.019000  74.797838      73.127500
# Middle East & North Africa  63.038000  75.545677      72.794000
# North America               78.639024  80.435976      79.732012
# South Asia                  63.081000  71.088625      68.354750
# Sub-Saharan Africa          52.554000  62.542100      60.020750

# %% [markdown]
# ## 10/09/2024 Homework question 3
#
# Group the dataset by Region and Income Group, calculate the average, min, and max of GDP per Capita & life Expentancy, total, average, min, and max of population, then save the result to Excel.

# %%
df_region = df.groupby(["Region", 'Income Group']).aggregate(
    {
     'Life expectancy at birth, total (years)': ['min', 'mean', 'max'],
     'GDP per capita (current US$)': ['min', 'mean', 'max']
    }

)
df_region
# Out:
#                                                Life expectancy at birth, total (years)  \
#                                                                                    min
# Region                     Income Group
# East Asia & Pacific        High income                                       58.072000
#                            Low income                                        68.911000
#                            Lower middle income                               56.506000
#                            Upper middle income                               63.226000
# Europe & Central Asia      High income                                       68.422439
#                            Lower middle income                               66.028000
#                            Upper middle income                               65.470976
# Latin America & Caribbean  High income                                       64.930000
#                            Lower middle income                               46.019000
#                            Not classified                                    70.554000
#                            Upper middle income                               66.416000
# Middle East & North Africa High income                                       72.541000
#                            Low income                                        63.153000
#                            Lower middle income                               57.759000
#                            Upper middle income                               63.553000
# North America              High income                                       76.329268
# South Asia                 Low income                                        57.944000
#                            Lower middle income                               62.466000
#                            Upper middle income                               73.538000
# Sub-Saharan Africa         High income                                       72.131707
#                            Low income                                        46.038000
#                            Lower middle income                               42.125000
#                            Upper middle income                               51.246000
#
#                                                                       \
#                                                      mean        max
# Region                     Income Group
# East Asia & Pacific        High income          79.008345  85.497561
#                            Low income           71.391444  73.284000
#                            Lower middle income  68.286722  75.378000
#                            Upper middle income  70.263271  79.274000
# Europe & Central Asia      High income          79.282116  84.402439
#                            Lower middle income  69.572457  71.900000
#                            Upper middle income  73.151024  79.282000
# Latin America & Caribbean  High income          75.619890  82.190244
#                            Lower middle income  67.663347  74.054000
#                            Not classified       72.433056  73.196000
#                            Upper middle income  73.587982  79.484000
# Middle East & North Africa High income          78.657522  82.860976
#                            Low income           68.239056  73.881000
#                            Lower middle income  72.321778  79.729000
#                            Upper middle income  71.028963  75.241000
# North America              High income          79.915437  82.596610
# South Asia                 Low income           61.304722  63.565000
#                            Lower middle income  68.761370  76.399000
#                            Upper middle income  78.060722  80.116000
# Sub-Saharan Africa         High income          73.520732  77.236585
#                            Low income           58.070038  67.300000
#                            Lower middle income  59.386444  76.593000
#                            Upper middle income  62.608596  74.514634
#
#                                                GDP per capita (current US$)  \
#                                                                         min
# Region                     Income Group
# East Asia & Pacific        High income                          4644.355494
#                            Low income                                   NaN
#                            Lower middle income                   223.229847
#                            Upper middle income                  1136.755211
# Europe & Central Asia      High income                          3494.990564
#                            Lower middle income                   305.266044
#                            Upper middle income                   897.178495
# Latin America & Caribbean  High income                          1036.019877
#                            Lower middle income                   679.280054
#                            Not classified                       4287.631579
#                            Upper middle income                  1776.932258
# Middle East & North Africa High income                         10030.444426
#                            Low income                            420.622705
#                            Lower middle income                   813.897944
#                            Upper middle income                  1314.762559
# North America              High income                         32143.681408
# South Asia                 Low income                            221.830531
#                            Lower middle income                   279.724200
#                            Upper middle income                  3789.232014
# Sub-Saharan Africa         High income                          9748.955842
#                            Low income                            128.538423
#                            Lower middle income                   321.338633
#                            Upper middle income                  3407.850648
#
#
#                                                         mean            max
# Region                     Income Group
# East Asia & Pacific        High income          33874.637356   90873.602487
#                            Low income                    NaN            NaN
#                            Lower middle income   2122.056616    5045.504700
#                            Upper middle income   5829.903445   16743.376740
# Europe & Central Asia      High income          47933.522488  240862.182448
#                            Lower middle income   1687.491133    4827.845703
#                            Upper middle income   6046.010575   15974.622070
# Latin America & Caribbean  High income          23970.748125   99624.885444
#                            Lower middle income   1879.755160    3600.121635
#                            Not classified       10341.209099   15975.729375
#                            Upper middle income   7042.758897   56495.853487
# Middle East & North Africa High income          34258.951233   98041.362238
#                            Low income            2523.869070   11304.644928
#                            Lower middle income   3906.016421    9225.845155
#                            Upper middle income   5680.306747   15765.419791
# North America              High income          67679.379373  118774.790657
# South Asia                 Low income             473.657905     653.417479
#                            Lower middle income   1708.225731    4388.201906
#                            Upper middle income   8001.072809   11780.816910
# Sub-Saharan Africa         High income          13272.154230   16851.119765
#                            Low income             629.082869    3188.769287
#                            Lower middle income   1735.313146    5083.826851
#                            Upper middle income   7708.803806   19849.717767

# %%
df_region.to_excel("stats_by_region.xlsx")
