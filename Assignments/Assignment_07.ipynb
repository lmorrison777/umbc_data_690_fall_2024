# %% [markdown]
# <a href="https://colab.research.google.com/github/lmorrison777/umbc_data_690_fall_2024/blob/main/Assignment_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

pd.set_option("display.max_rows", None)

df = pd.read_csv("https://raw.githubusercontent.com/wcj365/python-stats-dataviz/refs/heads/master/fall2024/data/World_Development_Indicators_(WDI).csv")

# %%
df.describe(include="all")
# Out:
#               Year      Country  GDP per capita (current US$)  \
# count   4123.00000         4123                   3962.000000
# unique         NaN          217                           NaN
# top            NaN  Afghanistan                           NaN
# freq           NaN           19                           NaN
# mean    2013.00000          NaN                  17007.692848
# std        5.47789          NaN                  25733.109164
# min     2004.00000          NaN                    128.538423
# 25%     2008.00000          NaN                   1862.892400
# 50%     2013.00000          NaN                   6048.304202
# 75%     2018.00000          NaN                  22137.309568
# max     2022.00000          NaN                 240862.182448
#
#         Life expectancy at birth, total (years)  Population, total  \
# count                               3777.000000       4.123000e+03
# unique                                      NaN                NaN
# ...

# %%
df.sample(5).T
# Out:
#                                                         871   \
# Year                                                    2020
# Country                                          Congo, Rep.
# GDP per capita (current US$)                     2011.269479
# Life expectancy at birth, total (years)               63.785
# Population, total                                  5702174.0
# Country Code                                             COG
# Region                                   Sub-Saharan Africa
# Income Group                             Lower middle income
# Lending Type                                           Blend
#
#                                                         3368  \
# Year                                                    2009
# Country                                         South Africa
# GDP per capita (current US$)                      6444.18684
# Life expectancy at birth, total (years)               57.447
# ...

# %%
def assign_quartile(gdp):
  if gdp <= 1862.89:
    quartile = "1st Quartile"
  elif gdp > 1862.89 and gdp <= 6048.30:
    quartile = "2nd Quartile"
  elif gdp > 6048.30 and gdp <= 22137.31:
    quartile = "3rd Quartile"
  else:
    quartile = "4th Quartile"
  return quartile

hungary = assign_quartile(14294.25)
hungary
# Out:
# '3rd Quartile'

# %%
df_usa = df[df["Country Code"] == "USA"]
df_usa
# Out:
#       Year        Country  GDP per capita (current US$)  \
# 3914  2004  United States                  41724.631629
# 3915  2005  United States                  44123.407068
# 3916  2006  United States                  46302.000880
# 3917  2007  United States                  48050.223777
# 3918  2008  United States                  48570.045980
# 3919  2009  United States                  47194.943355
# 3920  2010  United States                  48650.643128
# 3921  2011  United States                  50065.966504
# 3922  2012  United States                  51784.418574
# 3923  2013  United States                  53291.127689
# 3924  2014  United States                  55123.849787
# 3925  2015  United States                  56762.729452
# 3926  2016  United States                  57866.744934
# 3927  2017  United States                  59907.754261
# 3928  2018  United States                  62823.309438
# 3929  2019  United States                  65120.394663
# ...

# %%
assign_quartile(76329.5)
# Out:
# '4th Quartile'

# %%
df_2020 = df[df["Year"] == 2020]
df_2020.sample(3)
# Out:
#       Year   Country  GDP per capita (current US$)  \
# 4120  2020  Zimbabwe                   1372.696674
# 2429  2020    Mexico                   8894.890650
# 1517  2020      Guam                  34780.861662
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 4120                                   61.124         15669666.0          ZWE
# 2429                                   70.133        125998302.0          MEX
# 1517                                   76.612           169231.0          GUM
#
#                           Region         Income Group    Lending Type
# 4120         Sub-Saharan Africa   Lower middle income           Blend
# 2429  Latin America & Caribbean   Upper middle income            IBRD
# 1517         East Asia & Pacific          High income  Not classified

# %%
df_2020 = df_2020.copy()
df_2020.loc['Quartile'] = df_2020["GDP per capita (current US$)"].apply(assign_quartile)
df_2020.sample(5)
# Out:
#         Year               Country  GDP per capita (current US$)  \
# 947   2020.0                  Cuba                   9499.572504
# 3398  2020.0           South Sudan                           NaN
# 301   2020.0            Bangladesh                   2233.305901
# 3531  2020.0                 Sudan                    608.332520
# 3607  2020.0  Syrian Arab Republic                    537.090235
#
#       Life expectancy at birth, total (years)  Population, total Country Code  \
# 947                                    77.567         11300698.0          CUB
# 3398                                   55.480         10606227.0          SSD
# 301                                    71.968        167420951.0          BGD
# 3531                                   65.614         44440486.0          SDN
# 3607                                   72.140         20772595.0          SYR
#
#                           Region         Income Group    Lending Type
# ...

# %%
df_2020["GDP Quartile"] = df_2020["GDP per capita (current US$)"].apply(assign_quartile)

# %%
df_2020.sample(10)
# Out:
#             Year            Country  GDP per capita (current US$)  \
# 2106      2020.0            Lebanon                   5599.957523
# Quartile     NaN                NaN                           NaN
# 1156      2020.0  Equatorial Guinea                   6198.942524
# 1099      2020.0            Ecuador                   5645.199290
# 1365      2020.0        Gambia, The                    704.030463
# 795       2020.0              China                  10408.719554
# 2999      2020.0           Portugal                  22242.406418
# 16        2020.0        Afghanistan                    512.055098
# 1783      2020.0            Ireland                  85973.088488
# 2391      2020.0         Mauritania                   1836.292411
#
#           Life expectancy at birth, total (years)  Population, total  \
# 2106                                    77.804000       5.662923e+06
# Quartile                                      NaN                NaN
# ...

# %% [markdown]
# # Homework Question 1
# Save the summary statistics of all numerical columns and all categorical columns to only one Excel spreadsheet file with two worksheets, one for numerical and one for categorical columns.

# %%
df_2020_stats = df_2020.agg({
   'GDP per capita (current US$)' : ['mean', 'median', 'min', 'max'],
   'Life expectancy at birth, total (years)' : ['mean', 'median', 'min', 'max'],
   'Population, total' : ['mean', 'median', 'min', 'max']
})
df_2020_stats
# Out:
#         GDP per capita (current US$)  Life expectancy at birth, total (years)  \
# mean                    17545.865573                                72.309699
# median                   6370.903532                                72.889000
# min                       216.827417                                52.777000
# max                    182537.387370                                85.497561
#
#         Population, total
# mean         3.592913e+07
# median       6.579900e+06
# min          1.106900e+04
# max          1.411100e+09

# %%
from google.colab import files
df_2020_stats.to_excel('2020_output.xlsx', index=False)
files.download('2020_output.xlsx')

# %%
df_2020_cat_stats = df_2020['Region'].value_counts().reset_index()
df_2020_cat_stats[]
# Out:
#   File "<ipython-input-12-ff09a2ebfd62>", line 2
#     df_2020_cat_stats[]
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Homework Question 2
# Create a new column that is the GDP per Capita rounded to 2 decimal points by using the Python's build function "round" Hint: apply the round function/method and provide a parameter 2.

# %%
df_2020["Rounded GDP per Capita"] = df_2020["GDP per capita (current US$)"].round(2)
df_2020.sample(5)
